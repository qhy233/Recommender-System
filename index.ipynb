# %% [markdown]
# 《FunRec 推荐系统》
# ========================

# %% [markdown]
# ```eval_rst
# .. raw:: html
#    :file: frontpage.html
# ```

# %% [markdown]
# :begin_tab:toc
#  - [chapter_preface/index](chapter_preface/index.ipynb)
#  - [chapter_installation/index](chapter_installation/index.ipynb)
#  - [chapter_notation/index](chapter_notation/index.ipynb)
# :end_tab:

# %% [markdown]
# :begin_tab:toc
#  - [chapter_0_introduction/index](chapter_0_introduction/index.ipynb)
#  - [chapter_1_retrieval/index](chapter_1_retrieval/index.ipynb)
#  - [chapter_2_ranking/index](chapter_2_ranking/index.ipynb)
#  - [chapter_3_rerank/index](chapter_3_rerank/index.ipynb)
#  - [chapter_4_trends/index](chapter_4_trends/index.ipynb)
#  - [chapter_5_projects/index](chapter_5_projects/index.ipynb)
#  - [chapter_6_interview/index](chapter_6_interview/index.ipynb)
#  - [chapter_appendix/index](chapter_appendix/index.ipynb)
# :end_tab:

# %% [markdown]
# :begin_tab:toc
#  - [chapter_references/references](chapter_references/references.ipynb)
# :end_tab:
